# %%
#Let's go ahead and start with some imports
import pandas as pd
from pandas import Series,DataFrame
import numpy as np

# For Visualization
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline



# For time stamps
from datetime import datetime

# %%
import json

# %%
filepath = 'C:/Users/SW/Documents/GitHub/fund-data/2021/08/20/all.json'

# %%
data = pd.read_json(filepath,orient = 'values',encoding = 'utf-8')

# %%
data.head()
# Out:
#    code          name fromThisYear recent1Week recent1Month recent3Month  \
# 0   828     泰达转型机遇股票A        57.93       -2.17         7.06        50.66
# 1  1704  国投瑞银进宝灵活配置混合        58.50        2.11        20.17        58.06
# 2  1643   汇丰晋信智造先锋股票A        34.85       -2.12         5.75        27.36
# 3  1644   汇丰晋信智造先锋股票C        34.42       -2.13         5.71        27.20
# 4  3853     金鹰信息产业股票A        42.29       -1.33         6.36        43.70
#
#   recent6Month recent1Year recent2Year recent3Year  ... unitNetWorth  \
# 0        50.21      134.72      288.13      404.67  ...       3.5630
# 1        54.39      112.58      280.34      400.11  ...       4.4325
# 2           30      104.65      295.85      392.20  ...       4.0769
# 3        29.68      103.63      292.13      385.24  ...       3.9625
# 4        38.20       98.61      238.99      383.14  ...       4.3783
#
#   rank1Week  rank1Month  rank3Month  rank6Month  rank1Year  rank2Year  \
# ...

# %%
filepath1 = 'C:/Users/SW/Documents/GitHub/fund-data/2021/08/20/zhishu.json'

# %%
data1 = pd.read_json(filepath1,orient = 'values',encoding = 'utf-8')

# %%
data1[(data1['code']==51)&(data1['name'])&(data1['day'])&(data1['unitNetWorth'])][['code','name','day','unitNetWorth']]
# Out:
#      code           name         day unitNetWorth
# 350    51  华夏沪深300ETF联接A  2021-08-20       1.6313

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1225 entries, 0 to 1224
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           1225 non-null   int64
#  1   name           1225 non-null   object
#  2   fromThisYear   1225 non-null   object
#  3   recent1Week    1225 non-null   object
#  4   recent1Month   1225 non-null   object
#  5   recent3Month   1225 non-null   object
#  6   recent6Month   1225 non-null   object
#  7   recent1Year    1225 non-null   object
#  8   recent2Year    1225 non-null   object
#  9   recent3Year    1225 non-null   object
#  10  day            1225 non-null   object
#  11  unitNetWorth   1225 non-null   object
#  12  rank1Week      57 non-null     float64
#  13  rank1Month     57 non-null     float64
#  14  rank3Month     57 non-null     float64
#  15  rank6Month     57 non-null     float64
#  16  rank1Year      57 non-null     float64
# ...

# %%
filepath2 = 'C:/Users/SW/Documents/GitHub/fund-data/2021/08/20/zhishu.recommend.json'
data2 = pd.read_json(filepath2,orient = 'values',encoding = 'utf-8')

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57 entries, 0 to 56
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   code           57 non-null     int64
#  1   name           57 non-null     object
#  2   fromThisYear   57 non-null     float64
#  3   recent1Week    57 non-null     float64
#  4   recent1Month   57 non-null     float64
#  5   recent3Month   57 non-null     float64
#  6   recent6Month   57 non-null     float64
#  7   recent1Year    57 non-null     float64
#  8   recent2Year    57 non-null     float64
#  9   recent3Year    57 non-null     float64
#  10  day            57 non-null     object
#  11  unitNetWorth   57 non-null     float64
#  12  rank1Week      57 non-null     int64
#  13  rank1Month     57 non-null     int64
#  14  rank3Month     57 non-null     int64
#  15  rank6Month     57 non-null     int64
#  16  rank1Year      57 non-null     int64
# ...

# %%
data1.values[0][0]
# Out:
# [['2018-09-28', '0.9840', '3.3950', '0.41%', '开放申购', '开放赎回', ''],
#  ['2018-09-27', '0.9800', '3.3910', '-0.81%', '开放申购', '开放赎回', ''],
#  ['2018-09-26', '0.9880', '3.3990', '1.13%', '开放申购', '开放赎回', ''],
#  ['2018-09-25', '0.9770', '3.3880', '-1.01%', '开放申购', '开放赎回', ''],
#  ['2018-09-21', '0.9870', '3.3980', '1.86%', '开放申购', '开放赎回', ''],
#  ['2018-09-20', '0.9690', '3.3800', '-0.21%', '开放申购', '开放赎回', ''],
#  ['2018-09-19', '0.9710', '3.3820', '1.36%', '开放申购', '开放赎回', ''],
#  ['2018-09-18', '0.9580', '3.3690', '1.48%', '开放申购', '开放赎回', ''],
#  ['2018-09-17', '0.9440', '3.3550', '-1.15%', '开放申购', '开放赎回', ''],
#  ['2018-09-14', '0.9550', '3.3660', '-0.62%', '开放申购', '开放赎回', ''],
#  ['2018-09-13', '0.9610', '3.3720', '0.63%', '开放申购', '开放赎回', ''],
#  ['2018-09-12', '0.9550', '3.3660', '-0.62%', '开放申购', '开放赎回', ''],
#  ['2018-09-11', '0.9610', '3.3720', '-0.10%', '开放申购', '开放赎回', ''],
#  ['2018-09-10', '0.9620', '3.3730', '-1.23%', '开放申购', '开放赎回', ''],
# ...
